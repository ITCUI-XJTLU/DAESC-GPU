# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
path="/content/drive/My Drive/Stat_Gene/Data"

os.chdir(path)
os.listdir(path)

import time
import math
import numpy as np
import pandas as pd
from csv import reader
from scipy import special
from scipy.optimize import minimize
from scipy.optimize import Bounds

import matplotlib.pyplot as plt
from scipy.stats import chi2

# %%
import cupy as cp

# %% [markdown]
# # Version 5 for small dataset

# %%
# E - step self-defined kernel
sigmoid2_kernel = cp.ElementwiseKernel(
    'float32 x',
    'float32 mu',
    '''
    mu = 1 / (1 + exp(- x ));
    ''',
    'sigmoid2_kernel'
)

diff_trigamma_kernel = cp.ElementwiseKernel(
    'float32 x_small, int32 diff',  #for example  x_big = u/phi + y, x_small = u/phi
    'float32 result',
    '''
    result = 0 ;
    for (int i = 0; i < diff; i++){
      result = result - 1 / ( ( i + x_small) * (i + x_small) );
    }
    ''',
    'diff_trigamma_kernel'
)

diff_digamma_kernel = cp.ElementwiseKernel(
    'float32 x_small, int32 diff',  #for example  x_big = u/phi + y, x_small = u/phi
    'float32 result',
    '''
    result = 0 ;
    for (int i = 0; i < diff; i++){
      result = result + 1 / (  i + x_small ) ;
    }
    ''',
    'diff_digamma_kernel'
)



# M-step Define Kernel Function
dot_product_kernel = cp.ReductionKernel(
    'T x, T y',            # 输入变量的类型和名字
    'T z',                 # 输出变量的类型和名字
    'x * y',               # 输入元素的映射表达式（元素级乘法）
    'a + b',               # 归约操作（加法）
    'z = a',               # 输出操作（直接赋值）
    '0',                   # 归约的初始值
    'dot_product'          # 核函数的名称
)


sigmoid_kernel = cp.ElementwiseKernel(
    'float32 lp,float32 rand,float32 pre, float32 zmat',
    'float32 mu',
    '''
    mu = 1 / (1 + exp(-(lp + rand + zmat / pre)));
    ''',
    'sigmoid_kernel'
)

beta2_kernel = cp.ElementwiseKernel(
    'float32 a1, int32 y, float32 a2, int32 n',
    'float32 bt2',
    '''
    if (n < 0.1){
      bt2 = 0;
    }
    else{
      bt2 = lgamma(a1+y) + lgamma(a2+n-y) - lgamma(a1+a2+n) - lgamma(a1) - lgamma(a2) + lgamma(a1+a2);
    }
    ''',
    'beta2_kernel'
)


phiACC_kernel = cp.ElementwiseKernel(
    'float32 a1, float32 a2, int32 y, int32 n, float32 phi, float32 mu',
    'float32 temp_phi',
    '''
    if (n < 0.1 ){
      temp_phi = 0;
    }
    else{
      float temp_1 = 0.0 ;
      for (int i = 0; i < y; i++){
        temp_1 = temp_1 + 1 / (i + a1);
      }
      float temp_2 = 0.0 ;
      for (int i = 0; i < n-y; i++){
        temp_2 = temp_2 + 1 / (i + a2);
      }
      float temp_3 = 0.0 ;
      float phi_inv = 1 / phi;
      for (int i = 0; i < n; i++){
        temp_3 = temp_3 + 1 / (i + phi_inv);
      }
      temp_phi = - temp_1 * mu - temp_2 * (1 - mu) + temp_3;
    }
    ''',
    'phiACC_kernel'
)


bACC_kernel = cp.ElementwiseKernel(
    'float32 a1, float32 a2, int32 y, int32 n, float32 mu',
    'float32 temp_b',
    '''
    if ( n < 0.1 ){
      temp_b = 0;
    }
    else{
      float temp_1 = 0.0;
      for (int i = 0; i < y; i++){
        temp_1 = temp_1 + 1 / (i + a1);
      }
      float temp_2 = 0.0;
      for (int i = 0; i < n-y; i++){
        temp_2 = temp_2 + 1 / (i + a2);
      }
      temp_b = (temp_1 - temp_2) * mu * (1-mu);
    }
    ''',
    'bACC_kernel'
)

def cu_compute_randint_deriv_numpy(cu_linpred, cu_e_randint, cu_id_data, cu_e_y, cu_e_n, cu_e_phi, cu_inlcude_driv0 = False):
  lin = (cu_linpred + cp.matmul(cu_e_randint, cu_id_data)).astype(cp.float32)
  cu_e_mu = sigmoid2_kernel( lin )
  cu_e_mu = cp.clip(cu_e_mu,0.0000001, 0.9999999)

  cu_temp_1 = diff_digamma_kernel(cu_e_mu / cu_e_phi, cu_e_y) - diff_digamma_kernel((1 - cu_e_mu)/ cu_e_phi, cu_e_n - cu_e_y)

  cu_temp_2 = diff_trigamma_kernel(cu_e_mu / cu_e_phi, cu_e_y) + diff_trigamma_kernel((1 - cu_e_mu)/ cu_e_phi, cu_e_n - cu_e_y)

  cu_v1 = cu_temp_1 * cu_e_mu * (1 - cu_e_mu) / cu_e_phi
  cu_v2 = (cp.multiply(cp.multiply(cu_temp_2, cp.multiply(cu_e_mu,cu_e_mu)), cp.multiply(1- cu_e_mu, 1- cu_e_mu)) / (cu_e_phi * cu_e_phi) +
           cp.multiply(cp.multiply(cp.multiply(cu_temp_1, 1 - 2 * cu_e_mu), cu_e_mu), 1 - cu_e_mu) / cu_e_phi )
  cu_v1 = cp.matmul(cu_v1, cu_id_data.T)
  cu_v2 = cp.matmul(cu_v2, cu_id_data.T)

  if cu_inlcude_driv0:
    cu_v3 = beta2_kernel(cu_e_mu / cu_e_phi, cu_e_y, (1 - cu_e_mu)/ cu_e_phi, cu_e_n)
    cu_v3 = cp.matmul(cu_v3, cu_id_data.T)
    cu_v =  cp.concatenate((cu_v1,cu_v2,cu_v3),axis=0)
  else:
    cu_v =  cp.concatenate((cu_v1,cu_v2),axis=0)
  return cu_v

# Q-function for numpy
def cu_q_function(param, cu_x_q, cu_y_q, cu_n_q, cu_zmat_q, cu_ghq_weights_q, cu_randint_q, cu_randint_prec_q, cu_id_data_q,
                  cu_num_genes_q, cu_lower):
    q_start = time.time()
    cu_y_q = cu_y_q.astype(cp.int32)
    cu_n_q = cu_n_q.astype(cp.int32)
    #################################################################################################################################
    # 计算q-函数
    #数据升维
    cu_param = ((cp.asarray(param)).astype(cp.float32)).reshape(cu_num_genes_q,-1) # 我们输入的参数必须为一维的，这里我们把参数升级为原本的二维

    cu_b_q = cu_param[:,:-1]
    cu_b_q = cu_b_q.reshape(cu_b_q.shape[0],1,cu_b_q.shape[1]) # cu_b shape[5,1,2]
    cu_phi_q = cu_param[:,-1]
    cu_phi_q = cp.abs(cu_phi_q.reshape(cu_phi_q.shape[0],1,1)) # cu_phi_shape: [5,1,1] # 这里我们需要取 phi的绝对值
    cu_y_q = cu_y_q.reshape(cu_y_q.shape[0],cu_y_q.shape[1],1)
    cu_n_q = cu_n_q.reshape(cu_n_q.shape[0],cu_n_q.shape[1],1)


    cu_linpred_q = dot_product_kernel(cu_x_q, cu_b_q, axis = 2)
    cu_linpred_q = (cu_linpred_q).reshape(cu_num_genes_q,cu_zmat_q.shape[1],1)

    # print(f"cu_linpred_q:{cu_linpred_q.dtype}, cu_randint_q:{cu_randint_q.dtype}, cu_randint_prec_q:{cu_randint_prec_q.dtype}, cu_zmat_q:{cu_zmat_q.dtype}")
    cu_mu_q = sigmoid_kernel(cu_linpred_q, cu_randint_q, cu_randint_prec_q, cu_zmat_q)
    cu_mu_q = cp.clip(cu_mu_q,1e-5,1-1e-5)

    cu_alpha_1_q = cu_mu_q / cu_phi_q
    cu_alpha_2_q = (1 - cu_mu_q) / cu_phi_q

    cu_beta2 = beta2_kernel(cu_alpha_1_q, cu_y_q, cu_alpha_2_q, cu_n_q ) ## [5,3k,3] 并且在这里用deleter，消除误差
    cu_q_func_result = cp.sum(cu_beta2 ,axis=1) * cu_ghq_weights_q # # [5,3]

    # 最后把 五个基因的 q-fun 的结果加在一起
    cu_q_func_result = cu_lower - cp.sum(cu_q_func_result) # 这里仍然在GPU上

    #######################################################################################
    # 开始计算Q函数的导数
    # 求 b 的导数
    cu_deri_b_q1 = cu_x_q.reshape(cu_x_q.shape[0], cu_x_q.shape[1], cu_x_q.shape[2],1) # 升维成 [5, 3k, 2, 1]
    cu_deri_b_q2 = bACC_kernel(cu_alpha_1_q, cu_alpha_2_q, cu_y_q, cu_n_q, cu_mu_q)

    cu_deri_b_q2 = (cu_deri_b_q2).reshape(cu_deri_b_q2.shape[0], cu_deri_b_q2.shape[1], 1, cu_deri_b_q2.shape[2]) # dimension [5, 3k, 1, 3]
    cu_deri_b_q3 = cp.sum(cu_deri_b_q1 * cu_deri_b_q2, axis = 1) /cu_phi_q # dimension [5, 2, 3]
    cu_deri_b_q4 = cp.sum(cu_deri_b_q3 * cu_ghq_weights_q, axis = 2) # dimension [5,2]

    # phi 的导数
    cu_temp_phi_q = phiACC_kernel(cu_alpha_1_q, cu_alpha_2_q, cu_y_q, cu_n_q, cu_phi_q, cu_mu_q)

    cu_temp_phi_q = cp.sum(cu_temp_phi_q, axis=1) / np.square(cu_phi_q.reshape(-1,1)) # shape [5, 3]

    cu_deri_phi_q = cp.dot(cu_temp_phi_q, cu_ghq_weights_q.reshape(-1,1))

    # 合并导数，降维
    cu_deri = - cp.concatenate((cu_deri_b_q4, cu_deri_phi_q),axis=1).reshape(-1)
    cu_deri_q = cp.append(cu_deri, cu_q_func_result)

    cu_deri_q_result = (cp.asnumpy(cu_deri_q))
    cp.cuda.Stream.null.synchronize()
    end_q = time.time()
    return cu_deri_q_result[-1], cu_deri_q_result[:-1]

def cu_bbmix_lkl_agq_fixvar(cu_b_phi, cu_sigm2, cu_x, cu_randint, cu_id_data, cu_y, cu_n, cu_num_genes):
  cu_b = cu_b_phi[:, :-1]
  cu_b = cu_b.reshape(cu_b.shape[0], 1, cu_b.shape[1]) # shape[num_genes,1,2]
  cu_phi = cu_b_phi[:,-1]
  cu_phi = cu_phi.reshape(-1,1)
  cu_randint = cp.zeros_like(cu_randint)
  cu_linpred = dot_product_kernel(cu_x, cu_b, axis = 2)

  for i in range(3):
    cu_df = cu_compute_randint_deriv_numpy(cu_linpred, cu_randint, cu_id_data, cu_y, cu_n, cu_phi)
    cu_randint = cu_randint - 0.9 * (cu_df[:cu_num_genes,:] - cu_randint / cu_sigm2) / (cu_df[cu_num_genes:,:] - 1 / cu_sigm2)
  cp.cuda.Stream.null.synchronize()
  end_llkl_1 = time.time()


  cu_df = cu_compute_randint_deriv_numpy(cu_linpred, cu_randint, cu_id_data, cu_y, cu_n, cu_phi, cu_inlcude_driv0=True)
  cu_randint_prec = cp.abs(cu_df[cu_num_genes:cu_num_genes*2,:] - 1 / cu_sigm2)
  cu_fval = cu_df[cu_num_genes*2:,:] - cu_randint * cu_randint / cu_sigm2 / 2

  llkl = cp.sum(cu_fval - 0.5 * cp.log(cu_randint_prec),axis=1) - (int(cu_randint.shape[1]) * cp.log(cu_sigm2)/2).reshape(-1)
  return llkl


def cu_vem(cu_b_phi, cu_sigm2, cu_x, cu_randint, cu_randint_prec, cu_id_data, cu_y, cu_n, cu_ghq_weights, cu_ghq_nodes, cu_n_lap, cu_num_genes, cu_lower,
           cu_iteration, null):
  # E-M Algorithm
  start_time = time.time()

  # E-step
  start_e = time.time()
  cu_b = cu_b_phi[:, :-1]
  cu_b = cu_b.reshape(cu_b.shape[0], 1, cu_b.shape[1]) # shape[num_genes,1,2]
  cu_phi = cu_b_phi[:,-1]
  cu_phi = cu_phi.reshape(-1,1)
  cu_linpred = dot_product_kernel(cu_x, cu_b, axis = 2)

  for i in range(2):
    cu_df = cu_compute_randint_deriv_numpy(cu_linpred, cu_randint, cu_id_data, cu_y, cu_n, cu_phi)
    cu_randint = cu_randint - 0.9 * (cu_df[:cu_num_genes,:] - cu_randint / cu_sigm2) / (cu_df[cu_num_genes:,:] - 1 / cu_sigm2)
  cu_df = cu_compute_randint_deriv_numpy(cu_linpred, cu_randint, cu_id_data, cu_y, cu_n, cu_phi)
  cu_randint_prec = cp.abs(cu_df[cu_num_genes:,:] - 1 / cu_sigm2)
  cp.cuda.Stream.null.synchronize()
  end_e = time.time()
  #print("E-step used Time: " + str(end_e - start_e) + " s")

  # M - step
  start_m = time.time()
  cu_zmat = cp.multiply(cp.zeros((cu_y.shape[0],cu_y.shape[1],3)) + 1, cu_ghq_nodes).astype(cp.float32)
  cu_sigm2 =  (cp.mean( cu_randint * cu_randint + cp.reciprocal(cu_randint_prec), axis = 1)).reshape(-1,1)

  cu_b_phi = cp.asnumpy(cu_b_phi).astype(np.float32)
  if null == False:
    low_bound = (np.ones_like(cu_b_phi) * np.array([-np.inf, -np.inf, 1e-6]).reshape(1,-1)).reshape(-1) # 这里我们需要用有边界限制的优化器，这是下界
    up_bound = (np.ones_like(cu_b_phi) * np.array([np.inf, np.inf, np.inf]).reshape(1,-1)).reshape(-1) # 这里我们需要用有边界限制的优化器，这是上界
  else:
    low_bound = (np.ones_like(cu_b_phi) * np.array([-np.inf, 1e-6]).reshape(1,-1)).reshape(-1) # 这里我们需要用有边界限制的优化器，这是下界
    up_bound = (np.ones_like(cu_b_phi) * np.array([np.inf, np.inf]).reshape(1,-1)).reshape(-1) # 这里我们需要用有边界限制的优化器，这是上界

  cu_randint_vector = (cp.matmul(cu_randint, cu_id_data)).reshape(cu_num_genes, cu_zmat.shape[1], 1) # 提前计算a_i，并且变成和n一样大小的向量
  cu_precision_vector = (cp.matmul(cp.sqrt(cu_randint_prec), cu_id_data)).reshape(cu_num_genes, cu_zmat.shape[1], 1) # 提前计算precision，并且变成和n一样大小的向量

  #转化数据类型
  cu_randint_vector = cu_randint_vector.astype(cp.float32)
  cu_precision_vector = cu_precision_vector.astype(cp.float32)
  # 开始 优化函数
  cu_optim_result = minimize(cu_q_function, cu_b_phi.reshape(-1), method='L-BFGS-B', bounds = Bounds(low_bound,up_bound),
                            jac = True,
                            options={'maxls':100, 'ftol':1e7*np.finfo(float).eps},
                            args = (cu_x, cu_y, cu_n, cu_zmat, cu_ghq_weights, cu_randint_vector, cu_precision_vector, cu_id_data,
                            cu_num_genes, cu_lower))

  cu_b_phi = cp.asarray((cu_optim_result.x).reshape(cu_num_genes,-1))
  cu_b_phi = cu_b_phi.astype(cp.float32)
  cp.cuda.Stream.null.synchronize()
  end_m = time.time()
  #print("M-step used Time: " + str(end_m - start_m) + " s")
  #print(cu_optim_result)

  llkl = cu_bbmix_lkl_agq_fixvar(cu_b_phi, cu_sigm2, cu_x, cu_randint, cu_id_data, cu_y, cu_n, cu_num_genes)
  llkl = cp.asnumpy(llkl)
  cp.cuda.Stream.null.synchronize()
  end_llkl = time.time()
  #print("LLKL time: {} s".format(1*(end_llkl - end_m)))

  return cu_b_phi, cu_sigm2, llkl, cu_randint, cu_randint_prec


def daesc_cui(gene_index, num_iteration,
              ynxid_data,cu_id_data, cu_n_lap,initial_param, null, cum_time):
  # we wil block all codes, build a model which could train multiple genes at one time
  # in this function, we need to allow each genes getting different and suitable number of iteration of EM algorithm
  # 第一个很重要的参数 gene_index: 目前需要用DAESC模型拟合的基因的index

  # prepare some global data
  total_genes = int((ynxid_data.shape[0] - 1) / 2)
  cu_ghq_weights = cp.array([[0.1666667, 0.6666667, 0.1666667]]).astype(cp.float32).reshape(1,3)
  cu_ghq_nodes = cp.array([[-1.732051, -2.045201e-16, 1.732051]]).astype(cp.float32).reshape(1,3)

  # 初始参数 和 数据
  initial_param = initial_param[gene_index,:]
  if null == False: # under H1
    cu_param_result = cp.asarray(initial_param[:,[0,1,3]]).astype(cp.float32)
    cu_sigm2_result = cp.asarray(initial_param[:,[2]]).astype(cp.float32)
  else: # under H0
    cu_param_result = cp.asarray(initial_param[:,[4,7]]).astype(cp.float32)
    cu_sigm2_result = cp.asarray(initial_param[:,[6]]).astype(cp.float32)

  cu_randint_result = cp.zeros((len(gene_index),cu_id_data.shape[0]), dtype=cp.float32)
  cu_randint_prec_result = cp.ones_like(cu_randint_result,dtype = cp.float32) * 0

  cu_y_initial = (cp.asarray(ynxid_data[gene_index,:])).astype(cp.int32)
  cu_n_initial = (cp.asarray(ynxid_data[ np.array(gene_index) + total_genes,:])).astype(cp.int32)
  # cu_x_initial = cp.zeros((1,cu_y_initial.shape[1],2)).astype(cp.float32)
  cu_id_data = (cu_id_data).astype(cp.int32)

  if null == False:
    cu_x_initial = cp.zeros((1,cu_y_initial.shape[1],2))
    cu_x_initial[:,:,0] = cp.zeros((1,cu_y_initial.shape[1])) + 1
    cu_x_initial[:,:,1] = cp.asarray(ynxid_data[-1,:])
  else:
    cu_x_initial = cp.zeros((1,cu_y_initial.shape[1],1))
    cu_x_initial[:,:,0] = cp.zeros((1,cu_y_initial.shape[1])) + 1
  cu_x_initial = cu_x_initial.astype(cp.float32)

  gene_index = [i for i in range(len(gene_index))] # 这里，我们需要重新调整gene_index
  llkl_record_dict = {}
  speed_total = []
  for ele in gene_index:
    llkl_record_dict[ele] = [0]

  used_time = []

  # 开始 EM 算法
  for i in range(num_iteration):
    if len(gene_index) > 0:
      print()
      print("Iteration " + str(i) + " start: " + str(len(gene_index)) + " genes")
      start_em = time.time()

      # 在gene_index已知时，我们把数据提出来，放进DAESC模型里面
      start1 = time.time()
      cu_y = cu_y_initial[gene_index,:]
      cu_n = cu_n_initial[gene_index,:]
      cu_x = cu_x_initial[gene_index,:]

      cu_param = cu_param_result[gene_index,:] # b0, b1, phi
      cu_sigm2 = cu_sigm2_result[gene_index,:]
      cu_randint = cu_randint_result[gene_index,:]
      cu_randint_prec = cu_randint_result[gene_index,:]

      # 创建 cu_lower, 把q-function的值限制在很小的范围（每个基因贡献值小于5）
      cu_lower = 0
      if i != 0:
        for gene in gene_index:
          single_gene_llkl = llkl_record_dict[gene]
          cu_lower = cu_lower + single_gene_llkl[-1]
      cu_lower = cp.asarray(cu_lower, dtype = cp.float32)

      # EM 算法单次迭代
      cu_param, cu_sigm2, llkl, cu_randint, cu_randint_prec  = cu_vem(cu_param, cu_sigm2,
                                        cu_x, cu_randint, cu_randint_prec, cu_id_data, cu_y, cu_n,
                                        cu_ghq_weights, cu_ghq_nodes, cu_n_lap, len(gene_index), cu_lower,
                                        i, null)

      #开始把结果记录
      new_gene_index = []
      for gene in gene_index:
        (llkl_record_dict[gene])[0] += 1
        if llkl[gene_index.index(gene)] > (llkl_record_dict[gene])[-1] - 0.001 or i < 1:
          cu_param_result[gene_index,:] = cu_param
          cu_sigm2_result[gene_index,:] = cu_sigm2
          cu_randint_result[gene_index,:] = cu_randint
          cu_randint_prec_result[gene_index,:] = cu_randint_prec
          (llkl_record_dict[gene]).append(llkl[gene_index.index(gene)])
        if i < 10 :
          new_gene_index.append(gene)
        elif ( abs(((llkl_record_dict[gene])[-1] - (llkl_record_dict[gene])[-2]) / (llkl_record_dict[gene])[-1]) > 1e-7
            and (llkl_record_dict[gene])[-1] - (llkl_record_dict[gene])[-2] > - 0.001):
          new_gene_index.append(gene)
      gene_index = new_gene_index
      end_em = time.time()
      cum_time += end_em - start_em
      print(f"Iteration {i}, cummulative time = {cum_time} s")

  return cu_param_result, cu_sigm2_result, llkl_record_dict, cum_time

# %%
ynx_data = np.load("Simulation_Data/gene400_ynxid_data.npy")
ynx_data = ynx_data.T

id_data = np.load("Simulation_Data/one_hot_donor.npy")
id_data = id_data.T
cu_id_data = cp.asarray(id_data)

initial_param = np.load("Simulation_Data/gene400_initial_data.npy")

# %% [markdown]
# # Traing smaller dataset by T4 GPU

# %%
# Select gene index
# gene_index = [87,88, 89]
gene_index = [i for i in range(400)]
cum_time = 0.0

# Under H1
print(f"H1 Begins:")
my_param_result, my_sigm2_result, my_llkl_record_dict, cum_time = daesc_cui(gene_index,  num_iteration = 100,
                                                                            ynxid_data = ynx_data,
                                                                            cu_id_data = cu_id_data,
                                                                            cu_n_lap = 2 ,
                                                                            initial_param = initial_param,
                                                                            null = False, cum_time = cum_time)
# Under H0
print("\n \n H0 begins: \n")
my_param_null, my_sigm2_null, my_llkl_null, used_time_null = daesc_cui(gene_index,  num_iteration = 100,
                                                                            ynxid_data = ynx_data,
                                                                            cu_id_data = cu_id_data,
                                                                            cu_n_lap = 2 ,
                                                                            initial_param = initial_param,
                                                                            null = True, cum_time = cum_time)

print(f"Finally, we did finish training all genes using {cum_time} s")
# Out:
# H1 Begins:
#
# Iteration 0 start: 400 genes
# Iteration 0, cummulative time = 3.3834965229034424 s
#
# Iteration 1 start: 400 genes
# Iteration 1, cummulative time = 5.301051139831543 s
#
# Iteration 2 start: 400 genes
# Iteration 2, cummulative time = 6.907317399978638 s
#
# Iteration 3 start: 400 genes
# Iteration 3, cummulative time = 8.518257141113281 s
#
# Iteration 4 start: 400 genes
# Iteration 4, cummulative time = 10.36640453338623 s
#
# Iteration 5 start: 400 genes
# Iteration 5, cummulative time = 12.652134418487549 s
#
# Iteration 6 start: 400 genes
# Iteration 6, cummulative time = 14.424187660217285 s
#
# Iteration 7 start: 400 genes
# Iteration 7, cummulative time = 15.901460647583008 s
#
# Iteration 8 start: 400 genes
# Iteration 8, cummulative time = 17.64350390434265 s
#
# Iteration 9 start: 400 genes
# Iteration 9, cummulative time = 19.47019100189209 s
#
# Iteration 10 start: 400 genes
# Iteration 10, cummulative time = 21.03881573677063 s
#
# Iteration 11 start: 299 genes
# Iteration 11, cummulative time = 22.405345678329468 s
#
# Iteration 12 start: 297 genes
# Iteration 12, cummulative time = 23.81912636756897 s
#
# Iteration 13 start: 292 genes
# Iteration 13, cummulative time = 25.117864847183228 s
#
# Iteration 14 start: 286 genes
# Iteration 14, cummulative time = 26.368770837783813 s
#
# Iteration 15 start: 259 genes
# Iteration 15, cummulative time = 27.429872035980225 s
#
# Iteration 16 start: 252 genes
# Iteration 16, cummulative time = 28.424142122268677 s
#
# Iteration 17 start: 245 genes
# Iteration 17, cummulative time = 29.378854036331177 s
#
# Iteration 18 start: 241 genes
# Iteration 18, cummulative time = 30.23826575279236 s
#
# Iteration 19 start: 225 genes
# Iteration 19, cummulative time = 31.086165189743042 s
#
# Iteration 20 start: 224 genes
# Iteration 20, cummulative time = 32.05584359169006 s
#
# Iteration 21 start: 220 genes
# Iteration 21, cummulative time = 32.82048034667969 s
#
# Iteration 22 start: 217 genes
# Iteration 22, cummulative time = 33.71179485321045 s
#
# Iteration 23 start: 212 genes
# Iteration 23, cummulative time = 34.45539855957031 s
#
# Iteration 24 start: 209 genes
# Iteration 24, cummulative time = 35.2241895198822 s
#
# Iteration 25 start: 205 genes
# Iteration 25, cummulative time = 35.98582696914673 s
#
# Iteration 26 start: 181 genes
# Iteration 26, cummulative time = 36.77178359031677 s
#
# Iteration 27 start: 179 genes
# Iteration 27, cummulative time = 37.591763973236084 s
#
# Iteration 28 start: 172 genes
# Iteration 28, cummulative time = 38.344037771224976 s
#
# Iteration 29 start: 171 genes
# Iteration 29, cummulative time = 39.30430364608765 s
#
# Iteration 30 start: 163 genes
# Iteration 30, cummulative time = 39.97795367240906 s
#
# Iteration 31 start: 157 genes
# Iteration 31, cummulative time = 40.62837314605713 s
#
# Iteration 32 start: 155 genes
# Iteration 32, cummulative time = 41.40335464477539 s
#
# Iteration 33 start: 153 genes
# Iteration 33, cummulative time = 41.99977946281433 s
#
# Iteration 34 start: 151 genes
# Iteration 34, cummulative time = 42.60158371925354 s
#
# Iteration 35 start: 146 genes
# Iteration 35, cummulative time = 43.18406391143799 s
#
# Iteration 36 start: 144 genes
# Iteration 36, cummulative time = 43.76776456832886 s
#
# Iteration 37 start: 139 genes
# Iteration 37, cummulative time = 44.374152421951294 s
#
# Iteration 38 start: 138 genes
# Iteration 38, cummulative time = 44.91560482978821 s
#
# Iteration 39 start: 132 genes
# Iteration 39, cummulative time = 45.51811170578003 s
#
# Iteration 40 start: 129 genes
# Iteration 40, cummulative time = 46.295780658721924 s
#
# Iteration 41 start: 125 genes
# Iteration 41, cummulative time = 46.814478635787964 s
#
# Iteration 42 start: 118 genes
# Iteration 42, cummulative time = 47.37702536582947 s
#
# Iteration 43 start: 117 genes
# Iteration 43, cummulative time = 47.95879793167114 s
#
# Iteration 44 start: 115 genes
# Iteration 44, cummulative time = 48.48498725891113 s
#
# Iteration 45 start: 105 genes
# Iteration 45, cummulative time = 48.92695903778076 s
#
# Iteration 46 start: 102 genes
# Iteration 46, cummulative time = 49.43399143218994 s
#
# Iteration 47 start: 101 genes
# Iteration 47, cummulative time = 49.88096857070923 s
#
# Iteration 48 start: 100 genes
# Iteration 48, cummulative time = 50.30053448677063 s
#
# Iteration 49 start: 99 genes
# Iteration 49, cummulative time = 50.819889068603516 s
#
# Iteration 50 start: 97 genes
# Iteration 50, cummulative time = 51.34373497962952 s
#
# Iteration 51 start: 90 genes
# Iteration 51, cummulative time = 51.80459547042847 s
#
# Iteration 52 start: 86 genes
# Iteration 52, cummulative time = 52.24322199821472 s
#
# Iteration 53 start: 85 genes
# Iteration 53, cummulative time = 52.73187756538391 s
#
# Iteration 54 start: 83 genes
# Iteration 54, cummulative time = 53.241231203079224 s
#
# Iteration 55 start: 78 genes
# Iteration 55, cummulative time = 53.74017786979675 s
#
# Iteration 56 start: 76 genes
# Iteration 56, cummulative time = 54.11950349807739 s
#
# Iteration 57 start: 74 genes
# Iteration 57, cummulative time = 54.47688007354736 s
#
# Iteration 58 start: 74 genes
# Iteration 58, cummulative time = 54.83950424194336 s
#
# Iteration 59 start: 72 genes
# Iteration 59, cummulative time = 55.2175076007843 s
#
# Iteration 60 start: 71 genes
# Iteration 60, cummulative time = 55.5439612865448 s
#
# Iteration 61 start: 69 genes
# Iteration 61, cummulative time = 55.916316986083984 s
#
# Iteration 62 start: 69 genes
# Iteration 62, cummulative time = 56.24464130401611 s
#
# Iteration 63 start: 68 genes
# Iteration 63, cummulative time = 56.57913827896118 s
#
# Iteration 64 start: 66 genes
# Iteration 64, cummulative time = 56.95161318778992 s
#
# Iteration 65 start: 66 genes
# Iteration 65, cummulative time = 57.28846287727356 s
#
# Iteration 66 start: 65 genes
# Iteration 66, cummulative time = 57.68794012069702 s
#
# Iteration 67 start: 61 genes
# Iteration 67, cummulative time = 58.04295349121094 s
#
# Iteration 68 start: 55 genes
# Iteration 68, cummulative time = 58.30228066444397 s
#
# Iteration 69 start: 52 genes
# Iteration 69, cummulative time = 58.568578481674194 s
#
# Iteration 70 start: 51 genes
# Iteration 70, cummulative time = 58.824897050857544 s
#
# Iteration 71 start: 49 genes
# Iteration 71, cummulative time = 59.074891328811646 s
#
# Iteration 72 start: 48 genes
# Iteration 72, cummulative time = 59.33404517173767 s
#
# Iteration 73 start: 48 genes
# Iteration 73, cummulative time = 59.620497941970825 s
#
# Iteration 74 start: 47 genes
# Iteration 74, cummulative time = 59.86774444580078 s
#
# Iteration 75 start: 45 genes
# Iteration 75, cummulative time = 60.1458215713501 s
#
# Iteration 76 start: 40 genes
# Iteration 76, cummulative time = 60.43881797790527 s
#
# Iteration 77 start: 36 genes
# Iteration 77, cummulative time = 60.655582427978516 s
#
# Iteration 78 start: 36 genes
# Iteration 78, cummulative time = 60.90297889709473 s
#
# Iteration 79 start: 35 genes
# Iteration 79, cummulative time = 61.11830472946167 s
#
# Iteration 80 start: 35 genes
# Iteration 80, cummulative time = 61.40170335769653 s
#
# Iteration 81 start: 34 genes
# Iteration 81, cummulative time = 61.61669421195984 s
#
# Iteration 82 start: 34 genes
# Iteration 82, cummulative time = 61.90332293510437 s
#
# Iteration 83 start: 34 genes
# Iteration 83, cummulative time = 62.18818187713623 s
#
# Iteration 84 start: 31 genes
# Iteration 84, cummulative time = 62.42051649093628 s
#
# Iteration 85 start: 31 genes
# Iteration 85, cummulative time = 62.781975746154785 s
#
# Iteration 86 start: 29 genes
# Iteration 86, cummulative time = 63.012630462646484 s
#
# Iteration 87 start: 28 genes
# Iteration 87, cummulative time = 63.22796273231506 s
#
# Iteration 88 start: 27 genes
# Iteration 88, cummulative time = 63.51814103126526 s
#
# Iteration 89 start: 27 genes
# Iteration 89, cummulative time = 63.7370707988739 s
#
# Iteration 90 start: 27 genes
# Iteration 90, cummulative time = 63.95959234237671 s
#
# Iteration 91 start: 27 genes
# Iteration 91, cummulative time = 64.17450547218323 s
#
# Iteration 92 start: 27 genes
# Iteration 92, cummulative time = 64.38715100288391 s
#
# Iteration 93 start: 26 genes
# Iteration 93, cummulative time = 64.69780993461609 s
#
# Iteration 94 start: 26 genes
# Iteration 94, cummulative time = 64.88753080368042 s
#
# Iteration 95 start: 25 genes
# Iteration 95, cummulative time = 65.09669780731201 s
#
# Iteration 96 start: 25 genes
# Iteration 96, cummulative time = 65.3193256855011 s
#
# Iteration 97 start: 25 genes
# Iteration 97, cummulative time = 65.5508770942688 s
#
# Iteration 98 start: 25 genes
# Iteration 98, cummulative time = 65.74830317497253 s
#
# Iteration 99 start: 25 genes
# Iteration 99, cummulative time = 65.9788601398468 s
#
#
#  H0 begins:
#
#
# Iteration 0 start: 400 genes
# Iteration 0, cummulative time = 69.07415556907654 s
#
# Iteration 1 start: 400 genes
# Iteration 1, cummulative time = 70.76058173179626 s
#
# Iteration 2 start: 400 genes
# Iteration 2, cummulative time = 72.36345720291138 s
#
# Iteration 3 start: 400 genes
# Iteration 3, cummulative time = 74.29098987579346 s
#
# Iteration 4 start: 400 genes
# Iteration 4, cummulative time = 76.01712322235107 s
#
# Iteration 5 start: 400 genes
# Iteration 5, cummulative time = 77.71793699264526 s
#
# Iteration 6 start: 400 genes
# Iteration 6, cummulative time = 79.54331684112549 s
#
# Iteration 7 start: 400 genes
# Iteration 7, cummulative time = 81.17153787612915 s
#
# Iteration 8 start: 400 genes
# Iteration 8, cummulative time = 82.87787461280823 s
#
# Iteration 9 start: 400 genes
# Iteration 9, cummulative time = 84.3913197517395 s
#
# Iteration 10 start: 400 genes
# Iteration 10, cummulative time = 86.12240481376648 s
#
# Iteration 11 start: 318 genes
# Iteration 11, cummulative time = 87.36546516418457 s
#
# Iteration 12 start: 306 genes
# Iteration 12, cummulative time = 88.56719207763672 s
#
# Iteration 13 start: 299 genes
# Iteration 13, cummulative time = 89.657222032547 s
#
# Iteration 14 start: 278 genes
# Iteration 14, cummulative time = 90.63239908218384 s
#
# Iteration 15 start: 273 genes
# Iteration 15, cummulative time = 91.66608381271362 s
#
# Iteration 16 start: 266 genes
# Iteration 16, cummulative time = 92.74187850952148 s
#
# Iteration 17 start: 247 genes
# Iteration 17, cummulative time = 93.92088198661804 s
#
# Iteration 18 start: 243 genes
# Iteration 18, cummulative time = 94.97663474082947 s
#
# Iteration 19 start: 235 genes
# Iteration 19, cummulative time = 95.99002766609192 s
#
# Iteration 20 start: 229 genes
# Iteration 20, cummulative time = 96.85663533210754 s
#
# Iteration 21 start: 216 genes
# Iteration 21, cummulative time = 97.97837615013123 s
#
# Iteration 22 start: 212 genes
# Iteration 22, cummulative time = 98.79810643196106 s
#
# Iteration 23 start: 202 genes
# Iteration 23, cummulative time = 99.6148693561554 s
#
# Iteration 24 start: 196 genes
# Iteration 24, cummulative time = 100.36393547058105 s
#
# Iteration 25 start: 191 genes
# Iteration 25, cummulative time = 101.00112915039062 s
#
# Iteration 26 start: 188 genes
# Iteration 26, cummulative time = 101.70314955711365 s
#
# Iteration 27 start: 182 genes
# Iteration 27, cummulative time = 102.39466333389282 s
#
# Iteration 28 start: 176 genes
# Iteration 28, cummulative time = 103.06248044967651 s
#
# Iteration 29 start: 168 genes
# Iteration 29, cummulative time = 103.70882105827332 s
#
# Iteration 30 start: 162 genes
# Iteration 30, cummulative time = 104.30441641807556 s
#
# Iteration 31 start: 160 genes
# Iteration 31, cummulative time = 105.00046634674072 s
#
# Iteration 32 start: 158 genes
# Iteration 32, cummulative time = 105.63396334648132 s
#
# Iteration 33 start: 151 genes
# Iteration 33, cummulative time = 106.20195007324219 s
#
# Iteration 34 start: 151 genes
# Iteration 34, cummulative time = 106.82406497001648 s
#
# Iteration 35 start: 148 genes
# Iteration 35, cummulative time = 107.45903873443604 s
#
# Iteration 36 start: 144 genes
# Iteration 36, cummulative time = 108.10583877563477 s
#
# Iteration 37 start: 141 genes
# Iteration 37, cummulative time = 108.80538606643677 s
#
# Iteration 38 start: 138 genes
# Iteration 38, cummulative time = 109.43769860267639 s
#
# Iteration 39 start: 130 genes
# Iteration 39, cummulative time = 110.06068849563599 s
#
# Iteration 40 start: 125 genes
# Iteration 40, cummulative time = 110.56860995292664 s
#
# Iteration 41 start: 122 genes
# Iteration 41, cummulative time = 111.11648058891296 s
#
# Iteration 42 start: 118 genes
# Iteration 42, cummulative time = 111.52120423316956 s
#
# Iteration 43 start: 116 genes
# Iteration 43, cummulative time = 112.13642048835754 s
#
# Iteration 44 start: 111 genes
# Iteration 44, cummulative time = 112.60367941856384 s
#
# Iteration 45 start: 105 genes
# Iteration 45, cummulative time = 113.03725671768188 s
#
# Iteration 46 start: 101 genes
# Iteration 46, cummulative time = 113.47807574272156 s
#
# Iteration 47 start: 98 genes
# Iteration 47, cummulative time = 113.93658399581909 s
#
# Iteration 48 start: 95 genes
# Iteration 48, cummulative time = 114.38288521766663 s
#
# Iteration 49 start: 93 genes
# Iteration 49, cummulative time = 114.76070261001587 s
#
# Iteration 50 start: 93 genes
# Iteration 50, cummulative time = 115.26286387443542 s
#
# Iteration 51 start: 90 genes
# Iteration 51, cummulative time = 115.69193458557129 s
#
# Iteration 52 start: 87 genes
# Iteration 52, cummulative time = 116.11668229103088 s
#
# Iteration 53 start: 87 genes
# Iteration 53, cummulative time = 116.52669358253479 s
#
# Iteration 54 start: 84 genes
# Iteration 54, cummulative time = 116.9337215423584 s
#
# Iteration 55 start: 83 genes
# Iteration 55, cummulative time = 117.38065481185913 s
#
# Iteration 56 start: 77 genes
# Iteration 56, cummulative time = 117.70041227340698 s
#
# Iteration 57 start: 77 genes
# Iteration 57, cummulative time = 118.06072163581848 s
#
# Iteration 58 start: 75 genes
# Iteration 58, cummulative time = 118.48221945762634 s
#
# Iteration 59 start: 74 genes
# Iteration 59, cummulative time = 118.81698822975159 s
#
# Iteration 60 start: 72 genes
# Iteration 60, cummulative time = 119.16476392745972 s
#
# Iteration 61 start: 71 genes
# Iteration 61, cummulative time = 119.5512466430664 s
#
# Iteration 62 start: 67 genes
# Iteration 62, cummulative time = 119.94994759559631 s
#
# Iteration 63 start: 62 genes
# Iteration 63, cummulative time = 120.29270219802856 s
#
# Iteration 64 start: 58 genes
# Iteration 64, cummulative time = 120.68612384796143 s
#
# Iteration 65 start: 56 genes
# Iteration 65, cummulative time = 120.99350953102112 s
#
# Iteration 66 start: 54 genes
# Iteration 66, cummulative time = 121.29692125320435 s
#
# Iteration 67 start: 49 genes
# Iteration 67, cummulative time = 121.63845872879028 s
#
# Iteration 68 start: 47 genes
# Iteration 68, cummulative time = 121.93178200721741 s
#
# Iteration 69 start: 47 genes
# Iteration 69, cummulative time = 122.21466755867004 s
#
# Iteration 70 start: 46 genes
# Iteration 70, cummulative time = 122.46345782279968 s
#
# Iteration 71 start: 44 genes
# Iteration 71, cummulative time = 122.73909449577332 s
#
# Iteration 72 start: 42 genes
# Iteration 72, cummulative time = 123.01838970184326 s
#
# Iteration 73 start: 41 genes
# Iteration 73, cummulative time = 123.28391218185425 s
#
# Iteration 74 start: 40 genes
# Iteration 74, cummulative time = 123.52322053909302 s
#
# Iteration 75 start: 40 genes
# Iteration 75, cummulative time = 123.78336453437805 s
#
# Iteration 76 start: 38 genes
# Iteration 76, cummulative time = 124.0820689201355 s
#
# Iteration 77 start: 38 genes
# Iteration 77, cummulative time = 124.37687945365906 s
#
# Iteration 78 start: 36 genes
# Iteration 78, cummulative time = 124.65173077583313 s
#
# Iteration 79 start: 33 genes
# Iteration 79, cummulative time = 124.90842938423157 s
#
# Iteration 80 start: 32 genes
# Iteration 80, cummulative time = 125.24633884429932 s
#
# Iteration 81 start: 32 genes
# Iteration 81, cummulative time = 125.50226759910583 s
#
# Iteration 82 start: 32 genes
# Iteration 82, cummulative time = 125.65402436256409 s
#
# Iteration 83 start: 32 genes
# Iteration 83, cummulative time = 125.80667233467102 s
#
# Iteration 84 start: 32 genes
# Iteration 84, cummulative time = 125.95905137062073 s
#
# Iteration 85 start: 32 genes
# Iteration 85, cummulative time = 126.11276149749756 s
#
# Iteration 86 start: 32 genes
# Iteration 86, cummulative time = 126.26556420326233 s
#
# Iteration 87 start: 32 genes
# Iteration 87, cummulative time = 126.4180908203125 s
#
# Iteration 88 start: 32 genes
# Iteration 88, cummulative time = 126.57089495658875 s
#
# Iteration 89 start: 32 genes
# Iteration 89, cummulative time = 126.72412967681885 s
#
# Iteration 90 start: 32 genes
# Iteration 90, cummulative time = 126.87783980369568 s
#
# Iteration 91 start: 32 genes
# Iteration 91, cummulative time = 127.0324809551239 s
#
# Iteration 92 start: 32 genes
# Iteration 92, cummulative time = 127.18534111976624 s
#
# Iteration 93 start: 32 genes
# Iteration 93, cummulative time = 127.34045195579529 s
#
# Iteration 94 start: 32 genes
# Iteration 94, cummulative time = 127.49397087097168 s
#
# Iteration 95 start: 32 genes
# Iteration 95, cummulative time = 127.64676547050476 s
#
# Iteration 96 start: 32 genes
# Iteration 96, cummulative time = 127.80136108398438 s
#
# Iteration 97 start: 32 genes
# Iteration 97, cummulative time = 127.95585656166077 s
#
# Iteration 98 start: 32 genes
# Iteration 98, cummulative time = 128.1091628074646 s
#
# Iteration 99 start: 32 genes
# Iteration 99, cummulative time = 128.26208305358887 s
# Finally, we did finish training all genes using 65.9788601398468 s

# %%
# Calculate Type I error
# First, under H1
llkl_h1 = []
for key in my_llkl_record_dict.keys():
  llkl_h1.append(my_llkl_record_dict[key][-1])
llkl_h1 = np.array(llkl_h1)

# Second, under H0
llkl_null = []
for key in my_llkl_null.keys():
  llkl_null.append(my_llkl_null[key][-1])
llkl_null = np.array(llkl_null)

llkl2 = np.concatenate( (llkl_h1.reshape(-1,1), llkl_null.reshape(-1,1)), axis = 1)
tyep1 = np.mean(chi2.sf(2*(llkl2[:,0] - llkl2[:,1]), 1) < 0.05)
print(f"Type I error: {tyep1}")
# Out:
# Type I error: 0.0675

# %% [markdown]
# # Traing smaller dataset by A100 GPU

# %%
# Select gene index
# gene_index = [87,88, 89]
gene_index = [i for i in range(400)]
cum_time = 0.0

# Under H1
print(f"H1 Begins:")
my_param_result, my_sigm2_result, my_llkl_record_dict, cum_time = daesc_cui(gene_index,  num_iteration = 100,
                                                                            ynxid_data = ynx_data,
                                                                            cu_id_data = cu_id_data,
                                                                            cu_n_lap = 2 ,
                                                                            initial_param = initial_param,
                                                                            null = False, cum_time = cum_time)
# Under H0
print("\n \n H0 begins: \n")
my_param_null, my_sigm2_null, my_llkl_null, used_time_null = daesc_cui(gene_index,  num_iteration = 100,
                                                                            ynxid_data = ynx_data,
                                                                            cu_id_data = cu_id_data,
                                                                            cu_n_lap = 2 ,
                                                                            initial_param = initial_param,
                                                                            null = True, cum_time = cum_time)

print(f"Finally, we did finish training all genes using {cum_time} s")
# Out:
# H1 Begins:
#
# Iteration 0 start: 400 genes
# Iteration 0, cummulative time = 13.35936188697815 s
#
# Iteration 1 start: 400 genes
# Iteration 1, cummulative time = 14.150588035583496 s
#
# Iteration 2 start: 400 genes
# Iteration 2, cummulative time = 14.80172848701477 s
#
# Iteration 3 start: 400 genes
# Iteration 3, cummulative time = 15.385123491287231 s
#
# Iteration 4 start: 400 genes
# Iteration 4, cummulative time = 15.997272491455078 s
#
# Iteration 5 start: 400 genes
# Iteration 5, cummulative time = 16.602239847183228 s
#
# Iteration 6 start: 400 genes
# Iteration 6, cummulative time = 17.194197416305542 s
#
# Iteration 7 start: 400 genes
# Iteration 7, cummulative time = 17.82461643218994 s
#
# Iteration 8 start: 400 genes
# Iteration 8, cummulative time = 18.428810119628906 s
#
# Iteration 9 start: 400 genes
# Iteration 9, cummulative time = 19.035770654678345 s
#
# Iteration 10 start: 400 genes
# Iteration 10, cummulative time = 19.602322816848755 s
#
# Iteration 11 start: 306 genes
# Iteration 11, cummulative time = 20.061864376068115 s
#
# Iteration 12 start: 295 genes
# Iteration 12, cummulative time = 20.547300338745117 s
#
# Iteration 13 start: 284 genes
# Iteration 13, cummulative time = 21.08909797668457 s
#
# Iteration 14 start: 280 genes
# Iteration 14, cummulative time = 21.519195556640625 s
#
# Iteration 15 start: 275 genes
# Iteration 15, cummulative time = 21.934046506881714 s
#
# Iteration 16 start: 247 genes
# Iteration 16, cummulative time = 22.347352743148804 s
#
# Iteration 17 start: 241 genes
# Iteration 17, cummulative time = 22.762325763702393 s
#
# Iteration 18 start: 237 genes
# Iteration 18, cummulative time = 23.171567678451538 s
#
# Iteration 19 start: 233 genes
# Iteration 19, cummulative time = 23.626980543136597 s
#
# Iteration 20 start: 228 genes
# Iteration 20, cummulative time = 24.08340311050415 s
#
# Iteration 21 start: 223 genes
# Iteration 21, cummulative time = 24.46596908569336 s
#
# Iteration 22 start: 220 genes
# Iteration 22, cummulative time = 24.84051012992859 s
#
# Iteration 23 start: 212 genes
# Iteration 23, cummulative time = 25.216437339782715 s
#
# Iteration 24 start: 206 genes
# Iteration 24, cummulative time = 25.560923099517822 s
#
# Iteration 25 start: 182 genes
# Iteration 25, cummulative time = 25.93297266960144 s
#
# Iteration 26 start: 176 genes
# Iteration 26, cummulative time = 26.190495252609253 s
#
# Iteration 27 start: 172 genes
# Iteration 27, cummulative time = 26.465925931930542 s
#
# Iteration 28 start: 165 genes
# Iteration 28, cummulative time = 26.762101411819458 s
#
# Iteration 29 start: 163 genes
# Iteration 29, cummulative time = 27.118945360183716 s
#
# Iteration 30 start: 161 genes
# Iteration 30, cummulative time = 27.41774344444275 s
#
# Iteration 31 start: 157 genes
# Iteration 31, cummulative time = 27.709001302719116 s
#
# Iteration 32 start: 154 genes
# Iteration 32, cummulative time = 27.97747778892517 s
#
# Iteration 33 start: 148 genes
# Iteration 33, cummulative time = 28.259156942367554 s
#
# Iteration 34 start: 147 genes
# Iteration 34, cummulative time = 28.521278381347656 s
#
# Iteration 35 start: 144 genes
# Iteration 35, cummulative time = 28.810489177703857 s
#
# Iteration 36 start: 142 genes
# Iteration 36, cummulative time = 29.123724460601807 s
#
# Iteration 37 start: 136 genes
# Iteration 37, cummulative time = 29.395995378494263 s
#
# Iteration 38 start: 127 genes
# Iteration 38, cummulative time = 29.705108642578125 s
#
# Iteration 39 start: 122 genes
# Iteration 39, cummulative time = 29.95874810218811 s
#
# Iteration 40 start: 121 genes
# Iteration 40, cummulative time = 30.22374153137207 s
#
# Iteration 41 start: 118 genes
# Iteration 41, cummulative time = 30.448671340942383 s
#
# Iteration 42 start: 114 genes
# Iteration 42, cummulative time = 30.694955348968506 s
#
# Iteration 43 start: 113 genes
# Iteration 43, cummulative time = 30.92365264892578 s
#
# Iteration 44 start: 111 genes
# Iteration 44, cummulative time = 31.2472505569458 s
#
# Iteration 45 start: 109 genes
# Iteration 45, cummulative time = 31.50324010848999 s
#
# Iteration 46 start: 104 genes
# Iteration 46, cummulative time = 31.751322746276855 s
#
# Iteration 47 start: 96 genes
# Iteration 47, cummulative time = 31.9870662689209 s
#
# Iteration 48 start: 95 genes
# Iteration 48, cummulative time = 32.22037196159363 s
#
# Iteration 49 start: 93 genes
# Iteration 49, cummulative time = 32.45145273208618 s
#
# Iteration 50 start: 88 genes
# Iteration 50, cummulative time = 32.72091245651245 s
#
# Iteration 51 start: 85 genes
# Iteration 51, cummulative time = 32.95062613487244 s
#
# Iteration 52 start: 83 genes
# Iteration 52, cummulative time = 33.17283058166504 s
#
# Iteration 53 start: 82 genes
# Iteration 53, cummulative time = 33.363614082336426 s
#
# Iteration 54 start: 81 genes
# Iteration 54, cummulative time = 33.58890128135681 s
#
# Iteration 55 start: 72 genes
# Iteration 55, cummulative time = 33.78650522232056 s
#
# Iteration 56 start: 72 genes
# Iteration 56, cummulative time = 33.98080635070801 s
#
# Iteration 57 start: 72 genes
# Iteration 57, cummulative time = 34.173234701156616 s
#
# Iteration 58 start: 71 genes
# Iteration 58, cummulative time = 34.44086170196533 s
#
# Iteration 59 start: 70 genes
# Iteration 59, cummulative time = 34.76627445220947 s
#
# Iteration 60 start: 68 genes
# Iteration 60, cummulative time = 34.96171569824219 s
#
# Iteration 61 start: 62 genes
# Iteration 61, cummulative time = 35.13114285469055 s
#
# Iteration 62 start: 61 genes
# Iteration 62, cummulative time = 35.36793565750122 s
#
# Iteration 63 start: 60 genes
# Iteration 63, cummulative time = 35.57551717758179 s
#
# Iteration 64 start: 58 genes
# Iteration 64, cummulative time = 35.77978706359863 s
#
# Iteration 65 start: 58 genes
# Iteration 65, cummulative time = 35.99067211151123 s
#
# Iteration 66 start: 57 genes
# Iteration 66, cummulative time = 36.16505408287048 s
#
# Iteration 67 start: 56 genes
# Iteration 67, cummulative time = 36.36953091621399 s
#
# Iteration 68 start: 55 genes
# Iteration 68, cummulative time = 36.58387494087219 s
#
# Iteration 69 start: 55 genes
# Iteration 69, cummulative time = 36.79023218154907 s
#
# Iteration 70 start: 52 genes
# Iteration 70, cummulative time = 36.96578621864319 s
#
# Iteration 71 start: 51 genes
# Iteration 71, cummulative time = 37.174468755722046 s
#
# Iteration 72 start: 48 genes
# Iteration 72, cummulative time = 37.384844064712524 s
#
# Iteration 73 start: 45 genes
# Iteration 73, cummulative time = 37.66192054748535 s
#
# Iteration 74 start: 42 genes
# Iteration 74, cummulative time = 37.87357783317566 s
#
# Iteration 75 start: 38 genes
# Iteration 75, cummulative time = 38.067582845687866 s
#
# Iteration 76 start: 37 genes
# Iteration 76, cummulative time = 38.25124430656433 s
#
# Iteration 77 start: 35 genes
# Iteration 77, cummulative time = 38.43456816673279 s
#
# Iteration 78 start: 33 genes
# Iteration 78, cummulative time = 38.63610863685608 s
#
# Iteration 79 start: 32 genes
# Iteration 79, cummulative time = 38.81574845314026 s
#
# Iteration 80 start: 31 genes
# Iteration 80, cummulative time = 38.99407172203064 s
#
# Iteration 81 start: 31 genes
# Iteration 81, cummulative time = 39.17275786399841 s
#
# Iteration 82 start: 30 genes
# Iteration 82, cummulative time = 39.31885862350464 s
#
# Iteration 83 start: 29 genes
# Iteration 83, cummulative time = 39.467559814453125 s
#
# Iteration 84 start: 29 genes
# Iteration 84, cummulative time = 39.612560749053955 s
#
# Iteration 85 start: 28 genes
# Iteration 85, cummulative time = 39.77493500709534 s
#
# Iteration 86 start: 27 genes
# Iteration 86, cummulative time = 39.934619665145874 s
#
# Iteration 87 start: 27 genes
# Iteration 87, cummulative time = 40.130680322647095 s
#
# Iteration 88 start: 26 genes
# Iteration 88, cummulative time = 40.27034950256348 s
#
# Iteration 89 start: 25 genes
# Iteration 89, cummulative time = 40.4113655090332 s
#
# Iteration 90 start: 25 genes
# Iteration 90, cummulative time = 40.548177003860474 s
#
# Iteration 91 start: 25 genes
# Iteration 91, cummulative time = 40.68369936943054 s
#
# Iteration 92 start: 25 genes
# Iteration 92, cummulative time = 40.839224100112915 s
#
# Iteration 93 start: 25 genes
# Iteration 93, cummulative time = 41.00504279136658 s
#
# Iteration 94 start: 25 genes
# Iteration 94, cummulative time = 41.168818950653076 s
#
# Iteration 95 start: 24 genes
# Iteration 95, cummulative time = 41.30791711807251 s
#
# Iteration 96 start: 24 genes
# Iteration 96, cummulative time = 41.44694638252258 s
#
# Iteration 97 start: 24 genes
# Iteration 97, cummulative time = 41.58084177970886 s
#
# Iteration 98 start: 24 genes
# Iteration 98, cummulative time = 41.71625375747681 s
#
# Iteration 99 start: 24 genes
# Iteration 99, cummulative time = 41.84694719314575 s
#
#
#  H0 begins:
#
#
# Iteration 0 start: 400 genes
# Iteration 0, cummulative time = 43.1856050491333 s
#
# Iteration 1 start: 400 genes
# Iteration 1, cummulative time = 43.73928380012512 s
#
# Iteration 2 start: 400 genes
# Iteration 2, cummulative time = 44.317866563797 s
#
# Iteration 3 start: 400 genes
# Iteration 3, cummulative time = 44.97869944572449 s
#
# Iteration 4 start: 400 genes
# Iteration 4, cummulative time = 45.53676891326904 s
#
# Iteration 5 start: 400 genes
# Iteration 5, cummulative time = 46.0827317237854 s
#
# Iteration 6 start: 400 genes
# Iteration 6, cummulative time = 46.7740273475647 s
#
# Iteration 7 start: 400 genes
# Iteration 7, cummulative time = 47.31090831756592 s
#
# Iteration 8 start: 400 genes
# Iteration 8, cummulative time = 47.86981272697449 s
#
# Iteration 9 start: 400 genes
# Iteration 9, cummulative time = 48.439486503601074 s
#
# Iteration 10 start: 400 genes
# Iteration 10, cummulative time = 49.0836455821991 s
#
# Iteration 11 start: 358 genes
# Iteration 11, cummulative time = 49.72071170806885 s
#
# Iteration 12 start: 334 genes
# Iteration 12, cummulative time = 50.26363277435303 s
#
# Iteration 13 start: 312 genes
# Iteration 13, cummulative time = 50.791102170944214 s
#
# Iteration 14 start: 307 genes
# Iteration 14, cummulative time = 51.26553535461426 s
#
# Iteration 15 start: 280 genes
# Iteration 15, cummulative time = 51.700178146362305 s
#
# Iteration 16 start: 272 genes
# Iteration 16, cummulative time = 52.10089588165283 s
#
# Iteration 17 start: 240 genes
# Iteration 17, cummulative time = 52.56160831451416 s
#
# Iteration 18 start: 239 genes
# Iteration 18, cummulative time = 52.9298210144043 s
#
# Iteration 19 start: 234 genes
# Iteration 19, cummulative time = 53.339738607406616 s
#
# Iteration 20 start: 232 genes
# Iteration 20, cummulative time = 53.668943643569946 s
#
# Iteration 21 start: 207 genes
# Iteration 21, cummulative time = 53.9830162525177 s
#
# Iteration 22 start: 201 genes
# Iteration 22, cummulative time = 54.29435634613037 s
#
# Iteration 23 start: 199 genes
# Iteration 23, cummulative time = 54.66990351676941 s
#
# Iteration 24 start: 195 genes
# Iteration 24, cummulative time = 55.011080265045166 s
#
# Iteration 25 start: 192 genes
# Iteration 25, cummulative time = 55.44981408119202 s
#
# Iteration 26 start: 189 genes
# Iteration 26, cummulative time = 55.756242752075195 s
#
# Iteration 27 start: 187 genes
# Iteration 27, cummulative time = 56.07317233085632 s
#
# Iteration 28 start: 184 genes
# Iteration 28, cummulative time = 56.3945689201355 s
#
# Iteration 29 start: 176 genes
# Iteration 29, cummulative time = 56.74851989746094 s
#
# Iteration 30 start: 172 genes
# Iteration 30, cummulative time = 57.00111365318298 s
#
# Iteration 31 start: 159 genes
# Iteration 31, cummulative time = 57.31264638900757 s
#
# Iteration 32 start: 155 genes
# Iteration 32, cummulative time = 57.60480284690857 s
#
# Iteration 33 start: 150 genes
# Iteration 33, cummulative time = 57.852097272872925 s
#
# Iteration 34 start: 147 genes
# Iteration 34, cummulative time = 58.0576593875885 s
#
# Iteration 35 start: 144 genes
# Iteration 35, cummulative time = 58.3282196521759 s
#
# Iteration 36 start: 142 genes
# Iteration 36, cummulative time = 58.5962393283844 s
#
# Iteration 37 start: 136 genes
# Iteration 37, cummulative time = 58.87587571144104 s
#
# Iteration 38 start: 133 genes
# Iteration 38, cummulative time = 59.13135576248169 s
#
# Iteration 39 start: 131 genes
# Iteration 39, cummulative time = 59.39724540710449 s
#
# Iteration 40 start: 125 genes
# Iteration 40, cummulative time = 59.63743734359741 s
#
# Iteration 41 start: 123 genes
# Iteration 41, cummulative time = 59.92393922805786 s
#
# Iteration 42 start: 121 genes
# Iteration 42, cummulative time = 60.18040609359741 s
#
# Iteration 43 start: 114 genes
# Iteration 43, cummulative time = 60.417688608169556 s
#
# Iteration 44 start: 111 genes
# Iteration 44, cummulative time = 60.63192963600159 s
#
# Iteration 45 start: 111 genes
# Iteration 45, cummulative time = 61.00581359863281 s
#
# Iteration 46 start: 107 genes
# Iteration 46, cummulative time = 61.26984453201294 s
#
# Iteration 47 start: 103 genes
# Iteration 47, cummulative time = 61.50457143783569 s
#
# Iteration 48 start: 95 genes
# Iteration 48, cummulative time = 61.74153256416321 s
#
# Iteration 49 start: 91 genes
# Iteration 49, cummulative time = 61.98794102668762 s
#
# Iteration 50 start: 88 genes
# Iteration 50, cummulative time = 62.195244789123535 s
#
# Iteration 51 start: 85 genes
# Iteration 51, cummulative time = 62.41828012466431 s
#
# Iteration 52 start: 80 genes
# Iteration 52, cummulative time = 62.717695236206055 s
#
# Iteration 53 start: 77 genes
# Iteration 53, cummulative time = 62.97359848022461 s
#
# Iteration 54 start: 73 genes
# Iteration 54, cummulative time = 63.27093958854675 s
#
# Iteration 55 start: 72 genes
# Iteration 55, cummulative time = 63.50981283187866 s
#
# Iteration 56 start: 72 genes
# Iteration 56, cummulative time = 63.74089312553406 s
#
# Iteration 57 start: 70 genes
# Iteration 57, cummulative time = 63.94031000137329 s
#
# Iteration 58 start: 68 genes
# Iteration 58, cummulative time = 64.22179102897644 s
#
# Iteration 59 start: 66 genes
# Iteration 59, cummulative time = 64.46239376068115 s
#
# Iteration 60 start: 64 genes
# Iteration 60, cummulative time = 64.64887595176697 s
#
# Iteration 61 start: 61 genes
# Iteration 61, cummulative time = 64.87081360816956 s
#
# Iteration 62 start: 59 genes
# Iteration 62, cummulative time = 65.10337662696838 s
#
# Iteration 63 start: 58 genes
# Iteration 63, cummulative time = 65.34055042266846 s
#
# Iteration 64 start: 57 genes
# Iteration 64, cummulative time = 65.54147124290466 s
#
# Iteration 65 start: 55 genes
# Iteration 65, cummulative time = 65.75144648551941 s
#
# Iteration 66 start: 53 genes
# Iteration 66, cummulative time = 65.9206895828247 s
#
# Iteration 67 start: 52 genes
# Iteration 67, cummulative time = 66.13999581336975 s
#
# Iteration 68 start: 49 genes
# Iteration 68, cummulative time = 66.3167405128479 s
#
# Iteration 69 start: 49 genes
# Iteration 69, cummulative time = 66.54427766799927 s
#
# Iteration 70 start: 48 genes
# Iteration 70, cummulative time = 66.75318622589111 s
#
# Iteration 71 start: 46 genes
# Iteration 71, cummulative time = 66.98314094543457 s
#
# Iteration 72 start: 46 genes
# Iteration 72, cummulative time = 67.19548535346985 s
#
# Iteration 73 start: 46 genes
# Iteration 73, cummulative time = 67.39616346359253 s
#
# Iteration 74 start: 44 genes
# Iteration 74, cummulative time = 67.6231050491333 s
#
# Iteration 75 start: 44 genes
# Iteration 75, cummulative time = 67.81643176078796 s
#
# Iteration 76 start: 40 genes
# Iteration 76, cummulative time = 68.0008111000061 s
#
# Iteration 77 start: 40 genes
# Iteration 77, cummulative time = 68.34641551971436 s
#
# Iteration 78 start: 37 genes
# Iteration 78, cummulative time = 68.60434150695801 s
#
# Iteration 79 start: 35 genes
# Iteration 79, cummulative time = 68.75771975517273 s
#
# Iteration 80 start: 34 genes
# Iteration 80, cummulative time = 68.97781205177307 s
#
# Iteration 81 start: 33 genes
# Iteration 81, cummulative time = 69.11329627037048 s
#
# Iteration 82 start: 31 genes
# Iteration 82, cummulative time = 69.28081059455872 s
#
# Iteration 83 start: 30 genes
# Iteration 83, cummulative time = 69.43099617958069 s
#
# Iteration 84 start: 30 genes
# Iteration 84, cummulative time = 69.58104133605957 s
#
# Iteration 85 start: 30 genes
# Iteration 85, cummulative time = 69.74161672592163 s
#
# Iteration 86 start: 30 genes
# Iteration 86, cummulative time = 69.90197849273682 s
#
# Iteration 87 start: 30 genes
# Iteration 87, cummulative time = 70.03705739974976 s
#
# Iteration 88 start: 30 genes
# Iteration 88, cummulative time = 70.19571805000305 s
#
# Iteration 89 start: 30 genes
# Iteration 89, cummulative time = 70.36568975448608 s
#
# Iteration 90 start: 29 genes
# Iteration 90, cummulative time = 70.50332307815552 s
#
# Iteration 91 start: 28 genes
# Iteration 91, cummulative time = 70.63100504875183 s
#
# Iteration 92 start: 28 genes
# Iteration 92, cummulative time = 70.76482963562012 s
#
# Iteration 93 start: 26 genes
# Iteration 93, cummulative time = 70.92008996009827 s
#
# Iteration 94 start: 26 genes
# Iteration 94, cummulative time = 71.15120768547058 s
#
# Iteration 95 start: 25 genes
# Iteration 95, cummulative time = 71.28500556945801 s
#
# Iteration 96 start: 25 genes
# Iteration 96, cummulative time = 71.39939093589783 s
#
# Iteration 97 start: 25 genes
# Iteration 97, cummulative time = 71.56757593154907 s
#
# Iteration 98 start: 24 genes
# Iteration 98, cummulative time = 71.7105360031128 s
#
# Iteration 99 start: 23 genes
# Iteration 99, cummulative time = 71.83978796005249 s
# Finally, we did finish training all genes using 41.84694719314575 s

# %%
# Calculate Type I error
# First, under H1
llkl_h1 = []
for key in my_llkl_record_dict.keys():
  llkl_h1.append(my_llkl_record_dict[key][-1])
llkl_h1 = np.array(llkl_h1)

# Second, under H0
llkl_null = []
for key in my_llkl_null.keys():
  llkl_null.append(my_llkl_null[key][-1])
llkl_null = np.array(llkl_null)

llkl2 = np.concatenate( (llkl_h1.reshape(-1,1), llkl_null.reshape(-1,1)), axis = 1)
tyep1 = np.mean(chi2.sf(2*(llkl2[:,0] - llkl2[:,1]), 1) < 0.05)
print(f"Type I error: {tyep1}")
# Out:
# Type I error: 0.0725
